# %%
from annotation_generator import MimicAnnotationGenerator

# %%
generator = MimicAnnotationGenerator('data/eval_all.rttm')

# %%
next(generator)

# %%
next(generator)

# %%
next(generator)

# %%
next(generator)

# %%
next(generator)

# %%
ann = next(generator)

# %%
ann

# %%
print(ann)
# Out:
# [ 00:00:00.000 -->  00:00:06.000] C 2
# [ 00:00:04.616 -->  00:00:04.830] A 0
# [ 00:00:05.943 -->  00:00:06.000] B 1
